# %%
import pandas as pd

# %%
df_sim = pd.read_csv("sim.csv")

# %%
df_sim.dtypes
# Out:
# DTOBITO          object
# HORAOBITO        object
# CAUSABAS         object
# DTNASC           object
# SEXO              int64
# RACACOR          object
# CODMUNRES         int64
# CODMUNOCOR        int64
# TIPO_ACIDENTE    object
# IDADE             int64
# dtype: object

# %%
df_sim.isnull().sum()
# Out:
# DTOBITO          2696
# HORAOBITO           0
# CAUSABAS            0
# DTNASC            554
# SEXO                0
# IDADE               0
# RACACOR             0
# CODMUNRES           0
# CODMUNOCOR          0
# TIPO_ACIDENTE       0
# dtype: int64

# %%
df_sim.dtypes
# Out:
# DTOBITO           object
# HORAOBITO         object
# CAUSABAS          object
# DTNASC           float64
# SEXO               int64
# IDADE              int64
# RACACOR           object
# CODMUNRES          int64
# CODMUNOCOR         int64
# TIPO_ACIDENTE     object
# dtype: object

# %%
df_sim['IDADE'].head()
# Out:
# 0   -41
# 1   -84
# 2   -78
# 3   -66
# 4   -75
# Name: IDADE, dtype: int64
